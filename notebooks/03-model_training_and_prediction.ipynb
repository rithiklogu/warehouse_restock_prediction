# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd().parent

DATA_DIR = PROJECT_ROOT / "data"

RAW_DATA_DIR = DATA_DIR / "raw"

PRODUCTS_PATH = RAW_DATA_DIR / "Products.csv"
WAREHOUSES_PATH = RAW_DATA_DIR / "Warehouses.csv"
SALES_PATH = RAW_DATA_DIR / "Sales_History.csv"
INVENTORY_PATH = RAW_DATA_DIR / "Inventory.csv"

# %%
training_df.write_parquet(
    PROCESSED_DIR / "training_dataset.parquet"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 training_df.write_parquet(
#       2     PROCESSED_DIR / "training_dataset.parquet"
#       3 )
#
# NameError: name 'training_df' is not defined
